# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("E:\cards.csv")   # तुझ्या CSV फाइलचं नाव
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\DAMAYANTI\AppData\Local\Temp\ipykernel_27924\1675284660.py:1: SyntaxWarning: invalid escape sequence '\c'
#   df = pd.read_csv("E:\cards.csv")   # तुझ्या CSV फाइलचं नाव
#    class index                   filepaths        labels card type data set
# 0            0  train/ace of clubs/001.jpg  ace of clubs       ace    train
# 1            0  train/ace of clubs/002.jpg  ace of clubs       ace    train
# 2            0  train/ace of clubs/003.jpg  ace of clubs       ace    train
# 3            0  train/ace of clubs/004.jpg  ace of clubs       ace    train
# 4            0  train/ace of clubs/005.jpg  ace of clubs       ace    train

# %%
df.shape
# Out:
# (8155, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8155 entries, 0 to 8154
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   class index  8155 non-null   int64
#  1   filepaths    8155 non-null   object
#  2   labels       8155 non-null   object
#  3   card type    8155 non-null   object
#  4   data set     8155 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 318.7+ KB

# %%
df['labels'].value_counts()
# Out:
# labels
# ace of spades        191
# jack of spades       182
# ace of hearts        181
# jack of clubs        181
# jack of hearts       178
# seven of spades      175
# queen of diamonds    173
# queen of spades      172
# queen of clubs       171
# jack of diamonds     170
# eight of diamonds    169
# five of spades       168
# ten of spades        168
# six of spades        168
# four of clubs        167
# two of spades        165
# two of hearts        165
# four of hearts       164
# nine of spades       164
# three of diamonds    163
# eight of hearts      162
# six of clubs         162
# ten of diamonds      161
# king of spades       161
# five of clubs        160
# seven of hearts      153
# three of spades      152
# ten of clubs         151
# four of spades       150
# queen of hearts      149
# six of diamonds      149
# five of diamonds     148
# eight of clubs       148
# five of hearts       146
# eight of spades      145
# king of diamonds     145
# ...

# %% [markdown]
# # Data Visualization

# %%
for i, path in enumerate(sample['filepaths']):
    img = cv2.imread(path)
    if img is None:
        continue
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis('off')
plt.show()

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df.columns
# Out:
# Index(['class index', 'filepaths', 'labels', 'card type', 'data set'], dtype='object')

# %%
>>> import cv2
>>> cv2.__version__
# Out:
# '4.13.0'

# %%
from PIL import Image

sample = df.sample(5)

plt.figure(figsize=(10,5))
for i, path in enumerate(sample['filepaths']):
    img = Image.open(path)
    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 7
#       5 plt.figure(figsize=(10,5))
#       6 for i, path in enumerate(sample['filepaths']):
# ----> 7     img = Image.open(path)
#       8     plt.subplot(1,5,i+1)
#       9     plt.imshow(img)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\PIL\Image.py:3513, in open(fp, mode, formats)
#    3511 if is_path(fp):
#    3512     filename = os.fspath(fp)
# -> 3513     fp = builtins.open(filename, "rb")
#    3514     exclusive_fp = True
#    3515 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train/two of spades/155.jpg'

# %%
sample = df.sample(5)

plt.figure(figsize=(10,5))
for i, path in enumerate(sample['filepaths']):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[29], line 6
#       4 for i, path in enumerate(sample['filepaths']):
#       5     img = cv2.imread(path)
# ----> 6     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       7     plt.subplot(1,5,i+1)
#       8     plt.imshow(img)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
sample = df.sample(5)

plt.figure(figsize=(10,5))
for i, path in enumerate(sample['filepaths']):
    img = cv2.imread(path)
    if img is None:
        print("Image not found:", path)
        continue
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis('off')

plt.show()
# Out:
# Image not found: train/four of hearts/069.jpg
# Image not found: train/four of clubs/046.jpg
# Image not found: train/ace of spades/008.jpg
# Image not found: train/ace of spades/041.jpg
# Image not found: test/five of clubs/5.jpg

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
